# %% [markdown]
# <div style="background-color: #0C4C79; padding: 20px; text-align: center;">
#     <span style="font-size: 48px; color: #ffffff; font-family: cursive;">Hello everyone!</span>
# </div>

# %% [markdown]
# <h1 style="text-align:center; font-size: 30px;">
#     <span style="color:black;">Market Data Cleaning:</span>
#     <span style="color:black;">Handling Missing Values and Noise Removal</span>
# </h1>

# %% [markdown]
# <div style="display: flex; justify-content: center; gap: 10px;">
#     <img src="https://miro.medium.com/v2/resize:fit:1400/1*MNZnIscqOrXyA_Andu1czQ.png" style="width:100%; max-width:500px;">
#     <img src="https://smallbizclub.com/wp-content/uploads/2021/04/bigstock-Stock-Market-Or-Forex-Trading-389280844.jpg" style="width:100%; max-width:500px;">
# </div>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#0C4C79 ;margin:0;color:#ffffff ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">A Brief Explenation 💻</p>

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
# **Market Dataset and Data Cleaning Process**
#
#
# Financial data analysis is a crucial step in understanding market trends and extracting valuable insights for economic decision-making. The **Market** dataset contains information on **Open**, **High**, **Low**, **Close**, **Adjusted Close (Adj Close)** prices, and **Trading Volume**. This data can help market analysts examine price fluctuations and trading patterns. The dataset at hand contains historical financial market data, capturing price movements and trading volumes over various time periods. However, like many financial datasets, it may contain missing values and noise that could affect the accuracy of our analysis.
#
# In this study, the primary focus has been on **data cleaning**. The process involved **identifying and removing noise and invalid data**, such as **missing values** and **outliers**. After this stage, the cleaned data was used for **visual analysis and plotting charts**.
#
# By utilizing various charts, price trends and trading volume changes over different time periods were analyzed to gain better insights into market behavior. These steps are essential in financial data processing and can serve as a **foundation for future advanced modeling and analysis**.

# %% [markdown]
# <a id="0"></a>
# # <p style="padding:10px;background-color:#0C4C79 ;margin:0;color:#ffffff ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Table of Contents 💻</p>

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px; color: #'>
#
# * **[1. A Brief Explenation 💻](#1)**
#
#
# * **[2. Description of all columns in our dataset](#2)**
#
#
# * **[3. Import Libraries ](#3)**
#
#   - Libraries that we need in this project
#
#
# * **[4. call Dataset ](#4)**
#
#    - Calling the dataset (ٍEngland Weather dataset)
#
#
# * **[5. Exploratory Data Analysis (EDA) ](#5)**
#
#    - Get rid of missing values
#    - Get rid of Noises
#    - Sort all data and sort columns
#
#
# * **[6. Visulization of Data](#6)**
#    - Ploting & visualization

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#0C4C79 ;margin:0;color:#ffffff ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Description of all columns in our dataset</p>

# %% [markdown]
# <div style = 'border : 3px solid none; background-color:#f2f2f2; padding:10px'>
#
#
#  ## **Column Descriptions:**
#
#
# The dataset contains 112,457 rows and 8 columns. Below is an explanation of each column:
#
#
# Index:
#
# - Represents the stock market index or the specific stock symbol.
#
# Date:
#
# - Indicates the date for each record, which may need conversion to a proper datetime format.
#
# Open:
#
# - The price at which the stock or market opened on the given date.
#
# High:
#
# - The highest price reached by the stock or market on that date.
#
# Low:
#
# - The lowest price recorded for the stock or market on that date.
#
# Close:
#
# - The price at which the stock or market closed on that date.
#
# Adj Close:
#
# - The adjusted closing price, which accounts for dividends and stock splits.
#
# Volume:
#
# - The total number of shares traded on that particular day.

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#0C4C79 ;margin:0;color:#ffffff;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Import Libraries</p>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#0C4C79 ;margin:0;color:#ffffff;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Exploratory Data Analysis (EDA)</p>

# %%
data = pd.read_csv ('Market.xls')
data
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
new = data["Date"].str.split("/", n =  3 , expand = True)
 
data["Month"]= new[0]
 
data["Day"]= new[1]

data["Year"]= new[2]

data.drop(columns = ["Date"], inplace = True)

data
# Out:
#        Index         Open         High          Low        Close    Adj Close  \
# 0        NYA   528.690002   528.690002   528.690002   528.690002   528.690002
# 1        NYA   527.210022   527.210022   527.210022   527.210022   527.210022
# 2        NYA   527.840027   527.840027   527.840027   527.840027   527.840027
# 3        NYA   531.119995   531.119995   531.119995   531.119995   531.119995
# 4        NYA   532.070007   532.070007   532.070007   532.070007   532.070007
# ...      ...          ...          ...          ...          ...          ...
# 112452  N100  1241.119995  1251.910034  1241.119995  1247.069946  1247.069946
# 112453  N100  1249.469971  1259.209961  1249.030029  1256.599976  1256.599976
# 112454  N100  1256.079956  1258.880005  1248.140015  1248.930054  1248.930054
# 112455  N100  1254.609985  1265.660034  1254.609985  1258.579956  1258.579956
# 112456  N100  1258.489990  1263.709961  1258.239990  1263.619995  1263.619995
#
# ...

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#   - Now we want to display the time column in three categories, year, month and day, but the time columns go last, so we use the following code to sort the columns.

# %%
data.loc[:,['Index','Year', 'Day' ,'Month' ,'Open', 'High', 'Low','Close', 'Adj Close', 'Volume']]
# Out:
#        Index  Year Day Month         Open         High          Low  \
# 0        NYA  1965  31    12   528.690002   528.690002   528.690002
# 1        NYA  1966   3     1   527.210022   527.210022   527.210022
# 2        NYA  1966   4     1   527.840027   527.840027   527.840027
# 3        NYA  1966   5     1   531.119995   531.119995   531.119995
# 4        NYA  1966   6     1   532.070007   532.070007   532.070007
# ...      ...   ...  ..   ...          ...          ...          ...
# 112452  N100  2021  27     5  1241.119995  1251.910034  1241.119995
# 112453  N100  2021  28     5  1249.469971  1259.209961  1249.030029
# 112454  N100  2021  31     5  1256.079956  1258.880005  1248.140015
# 112455  N100  2021   1     6  1254.609985  1265.660034  1254.609985
# 112456  N100  2021   2     6  1258.489990  1263.709961  1258.239990
#
#               Close    Adj Close       Volume
# 0        528.690002   528.690002          0.0
# 1        527.210022   527.210022          0.0
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#        Index         Open         High          Low        Close    Adj Close  \
# 0        NYA   528.690002   528.690002   528.690002   528.690002   528.690002
# 1        NYA   527.210022   527.210022   527.210022   527.210022   527.210022
# 2        NYA   527.840027   527.840027   527.840027   527.840027   527.840027
# 3        NYA   531.119995   531.119995   531.119995   531.119995   531.119995
# 4        NYA   532.070007   532.070007   532.070007   532.070007   532.070007
# ...      ...          ...          ...          ...          ...          ...
# 112452  N100  1241.119995  1251.910034  1241.119995  1247.069946  1247.069946
# 112453  N100  1249.469971  1259.209961  1249.030029  1256.599976  1256.599976
# 112454  N100  1256.079956  1258.880005  1248.140015  1248.930054  1248.930054
# 112455  N100  1254.609985  1265.660034  1254.609985  1258.579956  1258.579956
# 112456  N100  1258.489990  1263.709961  1258.239990  1263.619995  1263.619995
#
# ...

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  110253.000000  110252.000000  110251.000000  110250.000000
# mean     7658.561932    7704.538416    7608.129749    7657.740822
# std      9011.455529    9066.605458    8954.536718    9011.555549
# min        54.869999      54.869999      54.869999      54.869999
# 25%      1855.060059    1864.687470    1844.015015    1855.347473
# 50%      5194.399902    5226.750000    5154.299805    5194.889892
# 75%     10134.299810   10207.827635   10060.369630   10134.867430
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume
# count  110244.000000  1.102530e+05
# mean     7657.982529  1.273975e+09
# std      9011.723572  4.315783e+09
# min        54.869999  0.000000e+00
# 25%      1855.057556  0.000000e+00
# 50%      5195.699951  4.329000e+05
# 75%     10135.512452  1.734314e+08
# max     68775.062500  9.440374e+10

# %%
df1 = df[df['Index'] == 'NYA']

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#
#   - First, we use the above command and extract the value of NYA from the Index column

# %%
df1
# Out:
#       Index          Open          High           Low         Close  \
# 0       NYA    528.690002    528.690002    528.690002    528.690002
# 1       NYA    527.210022    527.210022    527.210022    527.210022
# 2       NYA    527.840027    527.840027    527.840027    527.840027
# 3       NYA    531.119995    531.119995    531.119995    531.119995
# 4       NYA    532.070007    532.070007    532.070007    532.070007
# ...     ...           ...           ...           ...           ...
# 13943   NYA  16375.000000  16508.519530  16375.000000  16464.689450
# 13944   NYA  16464.689450  16525.810550  16375.150390  16390.189450
# 13945   NYA  16390.189450  16466.339840  16388.320310  16451.960940
# 13946   NYA  16451.960940  16546.359380  16451.960940  16531.949220
# 13947   NYA  16531.949220  16588.689450  16531.949220  16555.660160
#
#           Adj Close        Volume Month Day  Year
# 0        528.690002  0.000000e+00    12  31  1965
# ...

# %%
df2 = df1.dropna()
df2.describe(include = "all")
# Out:
#         Index          Open          High           Low         Close  \
# count   13932  13932.000000  13932.000000  13932.000000  13932.000000
# unique      1           NaN           NaN           NaN           NaN
# top       NYA           NaN           NaN           NaN           NaN
# freq    13932           NaN           NaN           NaN           NaN
# mean      NaN   4456.384785   4473.278937   4437.912527   4456.412120
# std       NaN   4074.980183   4095.100323   4052.942601   4075.604663
# min       NaN    347.769989    347.769989    347.769989    347.769989
# 25%       NaN    656.285004    656.392487    656.182511    656.182511
# 50%       NaN   2634.024903   2634.179931   2633.919922   2633.919922
# 75%       NaN   7348.750122   7384.077514   7281.324829   7346.784912
# max       NaN  16590.429690  16685.890630  16531.949220  16590.429690
#
#            Adj Close        Volume  Month    Day   Year
# count   13932.000000  1.393200e+04  13932  13932  13932
# ...

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#
#
#   - Now we use the dropna command to remove missing values

# %%
df2
# Out:
#       Index          Open          High           Low         Close  \
# 0       NYA    528.690002    528.690002    528.690002    528.690002
# 1       NYA    527.210022    527.210022    527.210022    527.210022
# 2       NYA    527.840027    527.840027    527.840027    527.840027
# 3       NYA    531.119995    531.119995    531.119995    531.119995
# 4       NYA    532.070007    532.070007    532.070007    532.070007
# ...     ...           ...           ...           ...           ...
# 13943   NYA  16375.000000  16508.519530  16375.000000  16464.689450
# 13944   NYA  16464.689450  16525.810550  16375.150390  16390.189450
# 13945   NYA  16390.189450  16466.339840  16388.320310  16451.960940
# 13946   NYA  16451.960940  16546.359380  16451.960940  16531.949220
# 13947   NYA  16531.949220  16588.689450  16531.949220  16555.660160
#
#           Adj Close        Volume Month Day  Year
# 0        528.690002  0.000000e+00    12  31  1965
# ...

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#   -  Now when we call our new dataset again, 16 rows were removed which were extra rows

# %%
df3 = df2.copy()
df3["Open"] = df3["Open"].astype(int)
df3["High"] = df3["High"].astype(int)
df3["Low"] = df3["Low"].astype(int)
df3["Close"] = df3["Close"].astype(int)
df3["Adj Close"] = df3["Adj Close"].astype(int)
df3["Volume"] = df3["Volume"].apply(np.int64) #### برای اینکه اعداد این مولفه منفی نشه از این دستور استفاده میکنیم

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#
#   -  Now we come up with the command and convert all columns that have decimal numbers to integers

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#0C4C79 ;margin:0;color:#ffffff;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Visulization of Data</p>

# %%
df3
# Out:
#       Index   Open   High    Low  Close  Adj Close      Volume Month Day  Year
# 0       NYA    528    528    528    528        528           0    12  31  1965
# 1       NYA    527    527    527    527        527           0     1   3  1966
# 2       NYA    527    527    527    527        527           0     1   4  1966
# 3       NYA    531    531    531    531        531           0     1   5  1966
# 4       NYA    532    532    532    532        532           0     1   6  1966
# ...     ...    ...    ...    ...    ...        ...         ...   ...  ..   ...
# 13943   NYA  16375  16508  16375  16464      16464  2947400000     5  24  2021
# 13944   NYA  16464  16525  16375  16390      16390  3420870000     5  25  2021
# 13945   NYA  16390  16466  16388  16451      16451  3674490000     5  26  2021
# 13946   NYA  16451  16546  16451  16531      16531  5201110000     5  27  2021
# 13947   NYA  16531  16588  16531  16555      16555  4199270000     5  28  2021
#
# ...

# %%
df3.hist(bins = 20 , figsize = (20, 15))
plt.show()

# %%
plt.figure(figsize=(20, 15))
sns.violinplot(data=df3, width=1, density_norm='count') 
plt.show()

# %%
plt.figure(figsize = (20, 15))
sns.boxplot(df1)
plt.show()

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#
#   - Now if we recall our data again, we will see that all the columns have their numbers converted to integers

# %%
np.mean(df3["Open"])
# Out:
# 4455.891975308642

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df3["Open"] , df3["Adj Close"])
plt.grid()
plt.xlabel('Open')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
df4  = df3[df3["Adj Close"] < 6110]
df4
# Out:
#       Index  Open  High   Low  Close  Adj Close      Volume Month Day  Year
# 0       NYA   528   528   528    528        528           0    12  31  1965
# 1       NYA   527   527   527    527        527           0     1   3  1966
# 2       NYA   527   527   527    527        527           0     1   4  1966
# 3       NYA   531   531   531    531        531           0     1   5  1966
# 4       NYA   532   532   532    532        532           0     1   6  1966
# ...     ...   ...   ...   ...    ...        ...         ...   ...  ..   ...
# 10956   NYA  5627  5761  5598   5761       5761  4499440000     7  13  2009
# 10957   NYA  5761  5805  5743   5805       5805  4149030000     7  14  2009
# 10958   NYA  5805  6003  5805   5993       5993  5238830000     7  15  2009
# 10959   NYA  5993  6065  5960   6043       6043  4898640000     7  16  2009
# 10960   NYA  6043  6054  6000   6038       6038  5141380000     7  17  2009
#
# [8908 rows x 10 columns]

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#   -  The graph above shows that the noise data in the range of 6110 was removed

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df4["Open"] , df4["Adj Close"])
plt.grid()
plt.xlabel('Open')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df3["Open"] , df3["Adj Close"])
plt.grid()
plt.xlabel('Open')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
df5 = df3[df3["Open"] > 5722]
df5
# Out:
#       Index   Open   High    Low  Close  Adj Close      Volume Month Day  Year
# 8095    NYA   5745   5745   5745   5745       5745           0     2  26  1998
# 8096    NYA   5754   5754   5754   5754       5754           0     2  27  1998
# 8097    NYA   5758   5758   5758   5758       5758           0     3   2  1998
# 8098    NYA   5782   5782   5782   5782       5782           0     3   3  1998
# 8099    NYA   5756   5756   5756   5756       5756           0     3   4  1998
# ...     ...    ...    ...    ...    ...        ...         ...   ...  ..   ...
# 13943   NYA  16375  16508  16375  16464      16464  2947400000     5  24  2021
# 13944   NYA  16464  16525  16375  16390      16390  3420870000     5  25  2021
# 13945   NYA  16390  16466  16388  16451      16451  3674490000     5  26  2021
# 13946   NYA  16451  16546  16451  16531      16531  5201110000     5  27  2021
# 13947   NYA  16531  16588  16531  16555      16555  4199270000     5  28  2021
#
# ...

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df5["Open"] , df5["Adj Close"])
plt.grid()
plt.xlabel('Open')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#
#   - The graph above shows that the noise data in the range of 5722 was removed

# %% [markdown]
# ##### Adj colse > 6000
# ##### Open < 5900

# %%
np.mean(df3["High"])
# Out:
# 4472.78265862762

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df3["High"] , df3["Adj Close"])
plt.grid()
plt.xlabel('High')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
df6 = df3[(df3["High"] < 6010) &(df3["High"] < 6002)]
df6
# Out:
#       Index  Open  High   Low  Close  Adj Close      Volume Month Day  Year
# 0       NYA   528   528   528    528        528           0    12  31  1965
# 1       NYA   527   527   527    527        527           0     1   3  1966
# 2       NYA   527   527   527    527        527           0     1   4  1966
# 3       NYA   531   531   531    531        531           0     1   5  1966
# 4       NYA   532   532   532    532        532           0     1   6  1966
# ...     ...   ...   ...   ...    ...        ...         ...   ...  ..   ...
# 10953   NYA  5654  5684  5552   5624       5624  5721780000     7   8  2009
# 10954   NYA  5624  5702  5624   5667       5667  4347170000     7   9  2009
# 10955   NYA  5667  5667  5583   5627       5627  3912080000     7  10  2009
# 10956   NYA  5627  5761  5598   5761       5761  4499440000     7  13  2009
# 10957   NYA  5761  5805  5743   5805       5805  4149030000     7  14  2009
#
# [8772 rows x 10 columns]

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df6["High"] , df6["Adj Close"])
plt.grid()
plt.xlabel('High')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#
#
#   -  The graph above shows that the noise data in the range 6002 to 6005 was removed

# %% [markdown]
# #### High < 6200

# %%
np.mean(df3["Low"])
# Out:
# 4437.415231122595

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df3["Low"] , df3["Adj Close"])
plt.grid()
plt.xlabel('Low')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
np.mean(df3["Close"])
# Out:
# 4455.917312661499

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df3["Close"] , df3["Adj Close"])
plt.grid()
plt.xlabel('Close')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df3["Volume"] , df3["Adj Close"])
plt.grid()
plt.xlabel('Volume')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
plt.figure(figsize = (10, 8))
plt.plot(df4["Year"] , df4["Adj Close"], color = 'darkblue')
plt.xticks(rotation = 90)
plt.xlabel('Year(TIME)',  fontsize = 13)
plt.ylabel('Adj Close(PRICE)',  fontsize = 13)
# Out:
# Text(0, 0.5, 'Adj Close(PRICE)')

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#   - We identified this noise

# %% [markdown]
# #### Adj colse > 6200
# #### Open < 5900
# #### High < 6200

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
#   - Now we move on to fixing the missing values

# %%
print("\n Show the missing values of Dataframe : \n\n", df3.isnull().sum())
# Out:
#  Show the missing values of Dataframe :
#
#  Index        0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Month        0
# Day          0
# Year         0
# dtype: int64

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
# Now we are done with missing values ​​and we need to move on to noise removal.
#
# Since we only want to measure the time graph with "Adj Close", we need to remove the noise in this graph as well.
#
# Given that in 1969 we have an abnormal return of up to 6000, this data should be removed.
#
# Now, since we found out from the Adj Close noise analysis that there is noise in the range of 6110, we can conclude that the abnormal limit in the time graph in 1969 is related to this noise.

# %%
print(df3[df3["Adj Close"] == 6110].index.values)
# Out:
# [  831  8870 10930]

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
# So in the range of 6110, its index is 831, so to eliminate that unevenness in the graph, we need to set that index to 611, which is the same as the other values.

# %%
df3.loc[831]
# Out:
# Index         NYA
# Open          611
# High          611
# Low           611
# Close         611
# Adj Close    6110
# Volume          0
# Month           5
# Day            29
# Year         1969
# Name: 831, dtype: object

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
#
# - Now "Adj Close" is equal to 611

# %%
df3.loc[831 , "Adj Close"] = 611

# %%
df3.loc[831]
# Out:
# Index         NYA
# Open          611
# High          611
# Low           611
# Close         611
# Adj Close     611
# Volume          0
# Month           5
# Day            29
# Year         1969
# Name: 831, dtype: object

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2 ; ;padding:10px'>
#
# - Now our graph is cleaned of that noisy data

# %%
plt.figure(figsize = (10, 8))
plt.plot(df3["Year"] , df3["Adj Close"], color = 'darkblue')
plt.xticks(rotation = 90)
plt.xlabel('Year(TIME)',  fontsize = 13)
plt.ylabel('Adj Close(PRICE)',  fontsize = 13)
# Out:
# Text(0, 0.5, 'Adj Close(PRICE)')
